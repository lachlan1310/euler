# %%
import numpy as np

# %%
goal = 200
coins = [200, 100, 50, 20 , 10, 5, 2, 1][::-1]
totals = [0 for _ in range(goal+1)]
totals[0] = 1
for c in coins:
    for j in range(c, len(totals)):
        totals[j]+= totals[j - c]

# %%
totals
# Out:
# [1,
#  1,
#  2,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  11,
#  12,
#  15,
#  16,
#  19,
#  22,
#  25,
#  28,
#  31,
#  34,
#  41,
#  44,
#  51,
#  54,
#  61,
#  68,
#  75,
#  82,
#  89,
#  96,
#  109,
#  116,
#  129,
#  136,
#  149,
#  162,
#  175,
#  188,
#  201,
#  214,
#  236,
#  249,
#  271,
#  284,
#  306,
#  328,
#  350,
#  372,
#  394,
#  416,
#  451,
#  473,
#  508,
#  530,
#  565,
#  600,
#  635,
#  670,
#  705,
#  740,
#  793,
#  828,
#  881,
#  916,
#  969,
#  1022,
#  1075,
#  1128,
#  1181,
#  1234,
#  1311,
#  1364,
#  1441,
#  1494,
#  1571,
#  1648,
#  1725,
#  1802,
#  1879,
#  1956,
#  2064,
#  2141,
#  2249,
#  2326,
#  2434,
#  2542,
#  2650,
#  2758,
#  2866,
#  2974,
#  3121,
#  3229,
#  3376,
#  3484,
#  3631,
#  3778,
#  3925,
#  4072,
#  4219,
#  4366,
#  4563,
#  4710,
#  4907,
#  5054,
#  5251,
#  5448,
#  5645,
#  5842,
#  6039,
#  6236,
#  6495,
#  6692,
#  6951,
#  7148,
#  7407,
#  7666,
#  7925,
#  8184,
#  8443,
#  8702,
#  9038,
#  9297,
# ...
